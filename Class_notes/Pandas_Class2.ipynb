# %% [markdown]
# <a href="https://colab.research.google.com/github/suyogy1-bot/Numpy_Pandas/blob/main/Pandas_Class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 2: DataFrame Basics
# Welcome to **Class 2**. Today we’ll learn how to **inspect**, **select**, and **organize** data inside a DataFrame.

# %% [markdown]
# ## 1 Inspecting Data
# Quick ways to understand your dataset:
# - `head(n)` → first *n* rows (default 5)
# - `tail(n)` → last *n* rows
# - `info()` → columns, non-null counts, and dtypes
# - `shape` → (rows, columns)
# - `dtypes` → data type of each column

# %%
import pandas as pd

# Create a small DataFrame
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "Score": [88, 92, 79, 85, 95]
}

b = pd.DataFrame(a)
print(b)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95

# %%
#1. .head() -> by default gives you starting 5 rows.
print(b.head(2))
# Out:
#     Name  Age  Score
# 0  Alice   25     88
# 1    Bob   30     92

# %%
#2. .tail() -> by default gives you last 5 rows.
print(b.tail(2))
# Out:
#     Name  Age  Score
# 3  David   40     85
# 4   Emma   22     95

# %%
#3. .info()
print(b.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Score   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None

# %%
#4 .shape -> It returns in tuple format, give rows and columns
print(b.shape)
# Out:
# (5, 3)

# %%
#5 dtypes -> data type of every column
print(b.dtypes)
# Out:
# Name     object
# Age       int64
# Score     int64
# dtype: object

# %% [markdown]
# ## 2 Selecting Columns & Rows
# Ways to access parts of a DataFrame:
# - Single column → `df['col']`
# - Multiple columns → `df[['col1','col2']]`
# - Label-based selection → `df.loc[row_label, col_label]`
# - Integer-index selection → `df.iloc[row_idx, col_idx]`
# Tip: `:` means "all rows/columns" in that dimension.

# %%
#1. Single column
print(b['Age'])
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    22
# Name: Age, dtype: int64

# %%
#2. Multiple columns
print(b[['Age','Score']])
# Out:
#    Age  Score
# 0   25     88
# 1   30     92
# 2   35     79
# 3   40     85
# 4   22     95

# %%
#3. Select only rows index 2 and column score
print(b.loc[2,'Score'])
# Out:
# 79

# %%
#4. Select using indexing we use .iloc()
print(b.iloc[0:4:2,0:2])
# Out:
#       Name  Age
# 0    Alice   25
# 2  Charlie   35

# %% [markdown]
# ## 3 Index & Columns Overview
# - `df.index` → row labels
# - `df.columns` → column names
# - `df.values` → underlying NumPy array (read-only; prefer using DataFrame ops)

# %%
#1. .index
print(b.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#2. .columns -> name of the columns
print(b.columns)
# Out:
# Index(['Name', 'Age', 'Score'], dtype='object')

# %%
#3. .values -> Dataframe convert into 2d array(Matrix)
print(b.values)
# Out:
# [['Alice' 25 88]
#  ['Bob' 30 92]
#  ['Charlie' 35 79]
#  ['David' 40 85]
#  ['Emma' 22 95]]

# %% [markdown]
# ## 4 Renaming Columns & Setting an Index
# - Rename columns → `df.rename(columns={'old':'new'}, inplace=False)`
# - Set a column as index → `df.set_index('column_name', inplace=False)`
# - Reset index → `df.reset_index(inplace=False)`
#  If you don't use `inplace=True`, remember to assign the result back to a variable.

# %%
print(b)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95

# %%
#1 .rename(old_name : new_name)
# Inplace -> Apply changes in original dataframe
b.rename(columns={'Score':'Marks'}, inplace=False)
# Out:
#       Name  Age  Marks
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95

# %%
#2 set_index
b.set_index('Name', inplace=False)
# Out:
#          Age  Score
# Name
# Alice     25     88
# Bob       30     92
# Charlie   35     79
# David     40     85
# Emma      22     95

# %%
#3 reset_index
b.reset_index(inplace=False)
# Out:
#    index     Name  Age  Score
# 0      0    Alice   25     88
# 1      1      Bob   30     92
# 2      2  Charlie   35     79
# 3      3    David   40     85
# 4      4     Emma   22     95

# %% [markdown]
# ## 5 Basic Attributes Recap
# - `df.columns` → names of all columns
# - `df.index` → row labels
# - `df.values` → NumPy array (data only)
# These are handy for quick checks and loops (though vectorized ops are preferred).

# %%
print(b.columns)
# Out:
# Index(['Name', 'Age', 'Score'], dtype='object')

# %%
print(b.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(b.values)
# Out:
# [['Alice' 25 88]
#  ['Bob' 30 92]
#  ['Charlie' 35 79]
#  ['David' 40 85]
#  ['Emma' 22 95]]

# %% [markdown]
# ## Mini Practice
# 1. Create a DataFrame with at least 5 rows and 4 columns (mix of numeric + text).
# 2. Show the first 3 rows, last 2 rows, and the info.
# 3. Select a sub-DataFrame with only 2 columns.
# 4. Rename one column and set any column as index, then reset it back.
# 5. Print `df.shape`, `df.dtypes`, and `df.columns`.

# %%
import pandas as pd

# Create a DataFrame with at least 5 rows & 4 columns (mix of numbers + text)
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "City": ["Delhi", "Mumbai", "Pune", "Bangalore", "Chennai"],
    "Score": [85, 91, 78, 88, 95]
}

df = pd.DataFrame(data)

# Show the first 3 rows, last 2 rows, and info
print(df.head(3))
print(df.tail(2))
print(df.info)

# Select a sub-DataFrame with only 2 columns
print(df[['Name','Age']])

# Rename one column and set any column as index, then reset it back
df.rename(columns={'Score':'Marks'}, inplace=False)
df.set_index('Name', inplace=False)
df.reset_index(inplace=False)

# Print df.shape, df.dtypes, and df.columns
print(df.shape)
print(df.dtypes)
print(df.columns)
# Out:
#       Name  Age    City  Score
# 0    Alice   25   Delhi     85
# 1      Bob   30  Mumbai     91
# 2  Charlie   35    Pune     78
#     Name  Age       City  Score
# 3  David   40  Bangalore     88
# 4   Emma   22    Chennai     95
# <bound method DataFrame.info of       Name  Age       City  Score
# 0    Alice   25      Delhi     85
# 1      Bob   30     Mumbai     91
# 2  Charlie   35       Pune     78
# 3    David   40  Bangalore     88
# 4     Emma   22    Chennai     95>
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4     Emma   22
# (5, 4)
# Name     object
# Age       int64
# City     object
# Score     int64
# dtype: object
# Index(['Name', 'Age', 'City', 'Score'], dtype='object')

# %% [markdown]
# ---
# ## ✅ Summary
# - You learned to **inspect** a DataFrame (`head`, `tail`, `info`, `shape`, `dtypes`).
# - You practiced **selecting** columns/rows using `[]`, `.loc`, and `.iloc`.
# - You explored **index/columns** and basic attributes.
# - You **renamed** columns and **set/reset** an index.
#
# Next up: **Data Cleaning Essentials** (missing values, types, duplicates).
